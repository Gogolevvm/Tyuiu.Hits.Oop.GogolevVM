// %% [markdown]
// Задание:

// %% [markdown]
// Ниже в блоке (Code) решите задачу
// Дан целочисленный массив numbers со следующими элементами { 5, 8, 1, 3, 9, 6, 7, 2 }, нужно выполнить следующие операции:
//
// 1. Найти минимальное и максимальное значения в массиве.
// 2. Найти сумму всех элементов массива.
// 3. Найти среднее арифметическое всех элементов массива.
// 4. Отсортировать массив в порядке возрастания.
// 5. Проверить, содержит ли массив определенное число.

// %%
int a = 0;
int[] numbers = [5, 8, 1, 3, 9, 6, 7, 2];

int min = numbers.Min();
int max = numbers.Max();

Console.WriteLine("Минимальным значением в массиве является: ");
Console.WriteLine(min);
Console.WriteLine("Максимальным значением в массиве является: ");
Console.WriteLine(max);
// Out:
// Минимальным значением в массиве является:
// 1
// Максимальным значением в массиве является:
// 9

// %%
int sum = numbers.Sum();
Console.WriteLine("Сумма всех элементов: " + sum);
// Out:
// Сумма всех элементов: 41

// %%
double average = numbers.Average();
Console.WriteLine("Среднее арифметическое: " + average);
// Out:
// Среднее арифметическое: 5,125

// %%
Array.Sort(numbers);
Console.WriteLine("Отсортированный массив: " + string.Join(", ", numbers));
// Out:
// Отсортированный массив: 1, 2, 3, 5, 6, 7, 8, 9

// %%
int searchNumber = 3;
bool contains = numbers.Contains(searchNumber);
Console.WriteLine($"Массив содержит число {searchNumber}: " + contains);
// Out:
// Массив содержит число 3: True
